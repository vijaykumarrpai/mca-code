# %% [markdown]
# # Simple Regression Model

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
import pandas as pd
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
# Load CSV and columns
df = pd.read_csv("D:/Study/MCA/4th Sem/DA/Hoteltips.csv")
df.head()
# Out:
#    meal_amt  tips
# 0        34     5
# 1       108    17
# 2        64    11
# 3        88     8
# 4       153    14

# %%
Y = df['tips']
X = df['meal_amt']
print(type(X))
X = X.values
X = X.reshape(len(X), 1)
print(X)
Y = Y.values
Y = Y.reshape(len(Y),1)
print(Y)
# Out:
# <class 'pandas.core.series.Series'>
# [[ 34]
#  [108]
#  [ 64]
#  [ 88]
#  [153]
#  [ 51]
#  [100]
#  [205]
#  [ 55]
#  [ 60]
#  [ 75]
#  [ 90]
#  [150]
#  [200]
#  [ 70]
#  [ 80]]
# [[ 5]
#  [17]
#  [11]
#  [ 8]
#  [14]
#  [ 5]
#  [15]
#  [10]
#  [ 5]
#  [ 5]
#  [10]
#  [10]
#  [20]
#  [10]
#  [ 5]
#  [10]]

# %%
# Split the data into training/testing sets
X_train = X[:-4]
X_test = X[-4:]
print(X_train)
print(X_test)
# Split the targets into training/testing sets
Y_train = Y[:-4]
Y_test = Y[-4:]
print(Y_train)
print(Y_test)
# Out:
# [[ 34]
#  [108]
#  [ 64]
#  [ 88]
#  [153]
#  [ 51]
#  [100]
#  [205]
#  [ 55]
#  [ 60]
#  [ 75]
#  [ 90]]
# [[150]
#  [200]
#  [ 70]
#  [ 80]]
# [[ 5]
#  [17]
#  [11]
#  [ 8]
#  [14]
#  [ 5]
#  [15]
#  [10]
#  [ 5]
#  [ 5]
#  [10]
#  [10]]
# [[20]
#  [10]
#  [ 5]
#  [10]]

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets - developing the model
regr.fit(X_train, Y_train)

# Predicting the model
Y_pred = regr.predict(X_test)

# Plot outputs
plt.plot(X_test, Y_pred, color = 'red', linewidth = 3)

# %%
rms = sqrt(mean_squared_error(Y_test, Y_pred))
print(rms)
# Out:
# 4.857374498950875

# %%
# Linear Regression works only on Numerical values
# Numerical values are used to train model

# %%
df = pd.read_csv("D:/Study/MCA/4th Sem/DA/Housing.csv")
df.head()
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0           1  42000.0     5850         3        1        2      yes      no
# 1           2  38500.0     4000         2        1        1      yes      no
# 2           3  49500.0     3060         3        1        1      yes      no
# 3           4  60500.0     6650         3        1        2      yes     yes
# 4           5  61000.0     6360         2        1        1      yes      no
#
#   fullbase gashw airco  garagepl prefarea
# 0      yes    no    no         1       no
# 1       no    no    no         0       no
# 2       no    no    no         0       no
# 3       no    no    no         0       no
# 4       no    no    no         0       no

# %%
Y = df['lotsize']
X = df['price']
print(type(X))
print(type(Y))
X = X.values
X = X.reshape(len(X), 1)
print(X)
Y = Y.values
Y = Y.reshape(len(Y), 1)
print(Y)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# [[ 42000.]
#  [ 38500.]
#  [ 49500.]
#  [ 60500.]
#  [ 61000.]
#  [ 66000.]
#  [ 66000.]
#  [ 69000.]
#  [ 83800.]
#  [ 88500.]
#  [ 90000.]
#  [ 30500.]
#  [ 27000.]
#  [ 36000.]
#  [ 37000.]
#  [ 37900.]
#  [ 40500.]
#  [ 40750.]
#  [ 45000.]
#  [ 45000.]
#  [ 48500.]
#  [ 65900.]
#  [ 37900.]
#  [ 38000.]
#  [ 42000.]
#  [ 42300.]
#  [ 43500.]
#  [ 44000.]
#  [ 44500.]
#  [ 44900.]
#  [ 45000.]
#  [ 48000.]
#  [ 49000.]
#  [ 51500.]
#  [ 61000.]
#  [ 61000.]
#  [ 61700.]
#  [ 67000.]
#  [ 82000.]
#  [ 54500.]
#  [ 66500.]
#  [ 70000.]
#  [ 82000.]
#  [ 92000.]
#  [ 38000.]
#  [ 44000.]
#  [ 41000.]
#  [ 43000.]
#  [ 48000.]
#  [ 54800.]
#  [ 55000.]
#  [ 57000.]
#  [ 68000.]
#  [ 95000.]
#  [ 38000.]
#  [ 25000.]
#  [ 25245.]
#  [ 56000.]
#  [ 35500.]
#  [ 30000.]
#  [ 48000.]
#  [ 48000.]
#  [ 52000.]
#  [ 54000.]
#  [ 56000.]
#  [ 60000.]
#  [ 60000.]
#  [ 67000.]
#  [ 47000.]
#  [ 70000.]
#  [ 45000.]
# ...

# %%
X_train = X[:-4]
X_test = X[-4:]
print(X_train)
print(X_train)
Y_train = Y[:-4]
Y_test = Y[-4:]
print(Y_train)
print(Y_train)
# Out:
# [[ 42000.]
#  [ 38500.]
#  [ 49500.]
#  [ 60500.]
#  [ 61000.]
#  [ 66000.]
#  [ 66000.]
#  [ 69000.]
#  [ 83800.]
#  [ 88500.]
#  [ 90000.]
#  [ 30500.]
#  [ 27000.]
#  [ 36000.]
#  [ 37000.]
#  [ 37900.]
#  [ 40500.]
#  [ 40750.]
#  [ 45000.]
#  [ 45000.]
#  [ 48500.]
#  [ 65900.]
#  [ 37900.]
#  [ 38000.]
#  [ 42000.]
#  [ 42300.]
#  [ 43500.]
#  [ 44000.]
#  [ 44500.]
#  [ 44900.]
#  [ 45000.]
#  [ 48000.]
#  [ 49000.]
#  [ 51500.]
#  [ 61000.]
#  [ 61000.]
#  [ 61700.]
#  [ 67000.]
#  [ 82000.]
#  [ 54500.]
#  [ 66500.]
#  [ 70000.]
#  [ 82000.]
#  [ 92000.]
#  [ 38000.]
#  [ 44000.]
#  [ 41000.]
#  [ 43000.]
#  [ 48000.]
#  [ 54800.]
#  [ 55000.]
#  [ 57000.]
#  [ 68000.]
#  [ 95000.]
#  [ 38000.]
#  [ 25000.]
#  [ 25245.]
#  [ 56000.]
#  [ 35500.]
#  [ 30000.]
#  [ 48000.]
#  [ 48000.]
#  [ 52000.]
#  [ 54000.]
#  [ 56000.]
#  [ 60000.]
#  [ 60000.]
#  [ 67000.]
#  [ 47000.]
#  [ 70000.]
#  [ 45000.]
#  [ 51000.]
#  [ 32500.]
#  [ 34000.]
#  [ 35000.]
#  [ 36000.]
# ...
